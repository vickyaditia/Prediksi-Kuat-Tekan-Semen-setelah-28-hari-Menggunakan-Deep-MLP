# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from scipy.stats import boxcox
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV

# %%
data = pd.read_excel('/content/PCC 18-19.xlsx')
data
# Out:
#      Tanggal  No Prod      SiO2    Al203    Fe203       CaO      MgO      SO3  \
# 0          1        1  25.32000  7.73000  3.65000  57.66000  1.02000  1.74000
# 1          2        2  25.33000  8.30000  3.63000  58.59000  1.07000  1.70000
# 2          3        3  24.41000  7.37000  3.53000  60.21000  1.15000  1.66000
# 3          4        4  26.68000  8.16000  3.72000  57.90000  1.12000  1.50000
# 4          5        5   0.00000  0.00000  0.00000   0.00000  0.00000  0.00000
# ..       ...      ...       ...      ...      ...       ...      ...      ...
# 725       27      726  21.20232  5.84573  3.13241  58.56837  1.13458  1.72713
# 726       28      727  21.43080  5.87385  3.17214  59.08322  1.07676  1.67198
# 727       29      728  21.34252  5.85900  3.16048  59.09016  1.11006  1.78500
# 728       30      729  21.40269  5.99123  3.14908  58.63324  1.09012  1.81234
# 729       31      730  23.44409  6.05867  3.20532  59.37500  1.21449  1.96669
#
#            FL       LOI    Residu      Blaine      Insol           3  \
# 0    1.852405  2.725639  6.452902  367.833498  12.171742  223.241592
# 1    2.073865  2.677858  7.148562  384.951085  11.381546  228.848116
# 2    1.480888  2.529241  6.360000  360.088768   9.069093  237.512744
# 3    1.480000  2.520000  8.280128  351.028479  14.170000  216.106016
# 4    0.000000  0.000000  0.000000    0.000000   0.000000    0.000000
# ..        ...       ...       ...         ...        ...         ...
# 725  0.352800  8.808290  6.340000  429.764962   9.283502  196.228340
# 726  0.086400  8.328732  6.430000  426.392890   8.699534  179.408768
# 727  0.100800  8.357934  7.290000  424.496209   8.702595  185.015292
# 728  0.194400  8.712950  6.570000  452.805285   9.593691  178.389400
# 729  0.381600  2.984496  6.430000  379.109054   7.442369  192.660552
#
#               7           28
# 0    292.558616   419.469932
# 1    292.558616   431.192664
# 2    299.184508   437.308872
# 3    279.816516   412.844040
# 4      0.000000     0.000000
# ..          ...          ...
# 725  276.248728  1912.334368
# 726  243.119268   318.042816
# 727  252.293580   304.791032
# 728  249.745160   334.352704
# 729  257.390420   353.211012
#
# [730 rows x 16 columns]

# %%
data.describe()
# Out:
#           Tanggal     No Prod        SiO2       Al203       Fe203         CaO  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean    15.720548  365.500000   14.258941    3.996681    1.969722   35.322332
# std      8.802278  210.877136   11.167695    3.130837    1.542155   27.453582
# min      1.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      8.000000  183.250000    0.000000    0.000000    0.000000    0.000000
# 50%     16.000000  365.500000   21.408655    5.974415    2.947105   54.925000
# 75%     23.000000  547.750000   22.698200    6.388705    3.146380   57.008277
# max     31.000000  730.000000   30.409970    8.300000    4.000000   67.870000
#
#               MgO         SO3          FL         LOI      Residu      Blaine  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.561764    1.110089    0.766078    4.675900    3.803604  266.946238
# std      0.454140    0.875330    0.675281    4.027930    3.209408  208.988393
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.792350    1.593000    0.900585    5.336997    4.585000  396.217474
# 75%      0.949500    1.840000    1.298391    8.771248    6.432690  439.149190
# max      1.342920    2.378100    3.302970   11.487026   11.884550  515.831366
#
#             Insol           3           7           28
# count  730.000000  730.000000  730.000000   730.000000
# mean     7.063207  124.374765  161.768339   213.591109
# std      5.853374   98.422726  127.673429   178.414688
# min      0.000000    0.000000    0.000000     0.000000
# 25%      0.000000    0.000000    0.000000     0.000000
# 50%      9.542118  179.408768  233.690114   310.397556
# 75%     11.609025  205.275231  264.908259   344.036700
# max     22.674128  266.564732  348.114172  1912.334368

# %%
data.isnull().sum()
# Out:
# Tanggal    0
# No Prod    0
# SiO2       0
# Al203      0
# Fe203      0
# CaO        0
# MgO        0
# SO3        0
# FL         0
# LOI        0
# Residu     0
# Blaine     0
# Insol      0
# 3          0
# 7          0
# 28         0
# dtype: int64

# %%
data.drop('Tanggal', axis=1, inplace=True)

# %%
data
# Out:
#      No Prod      SiO2    Al203    Fe203       CaO      MgO      SO3  \
# 0          1  25.32000  7.73000  3.65000  57.66000  1.02000  1.74000
# 1          2  25.33000  8.30000  3.63000  58.59000  1.07000  1.70000
# 2          3  24.41000  7.37000  3.53000  60.21000  1.15000  1.66000
# 3          4  26.68000  8.16000  3.72000  57.90000  1.12000  1.50000
# 4          5   0.00000  0.00000  0.00000   0.00000  0.00000  0.00000
# ..       ...       ...      ...      ...       ...      ...      ...
# 725      726  21.20232  5.84573  3.13241  58.56837  1.13458  1.72713
# 726      727  21.43080  5.87385  3.17214  59.08322  1.07676  1.67198
# 727      728  21.34252  5.85900  3.16048  59.09016  1.11006  1.78500
# 728      729  21.40269  5.99123  3.14908  58.63324  1.09012  1.81234
# 729      730  23.44409  6.05867  3.20532  59.37500  1.21449  1.96669
#
#            FL       LOI    Residu      Blaine      Insol           3  \
# 0    1.852405  2.725639  6.452902  367.833498  12.171742  223.241592
# 1    2.073865  2.677858  7.148562  384.951085  11.381546  228.848116
# 2    1.480888  2.529241  6.360000  360.088768   9.069093  237.512744
# 3    1.480000  2.520000  8.280128  351.028479  14.170000  216.106016
# 4    0.000000  0.000000  0.000000    0.000000   0.000000    0.000000
# ..        ...       ...       ...         ...        ...         ...
# 725  0.352800  8.808290  6.340000  429.764962   9.283502  196.228340
# 726  0.086400  8.328732  6.430000  426.392890   8.699534  179.408768
# 727  0.100800  8.357934  7.290000  424.496209   8.702595  185.015292
# 728  0.194400  8.712950  6.570000  452.805285   9.593691  178.389400
# 729  0.381600  2.984496  6.430000  379.109054   7.442369  192.660552
#
#               7           28
# 0    292.558616   419.469932
# 1    292.558616   431.192664
# 2    299.184508   437.308872
# 3    279.816516   412.844040
# 4      0.000000     0.000000
# ..          ...          ...
# 725  276.248728  1912.334368
# 726  243.119268   318.042816
# 727  252.293580   304.791032
# 728  249.745160   334.352704
# 729  257.390420   353.211012
#
# [730 rows x 15 columns]

# %% [markdown]
# karena banyak angka 0 dimana pada variabel indepen nya adalah 0 lalu di target nya juga 0 dan distribusi angka 0 terlalu banyak. maka variabel dengan angka 0 dan target 0 dihapus

# %%
data = data.drop(data[data[[28]].eq(0).all(axis=1)].index)

# %%
data.describe()
# Out:
#           No Prod        SiO2       Al203       Fe203         CaO         MgO  \
# 7        0.074672 -0.417698  0.023753 -0.358582 -0.256407  0.820601  1.000000
# 28       0.119818 -0.522115  0.188905 -0.462006 -0.257483  0.664026  0.745362
#
#                28
# No Prod -0.312422
# SiO2     0.077115
# Al203    0.310446
# Fe203    0.407714
# CaO      0.348994
# MgO     -0.237557
# SO3     -0.143131
# FL       0.119818
# LOI     -0.522115
# Residu   0.188905
# Blaine  -0.462006
# Insol   -0.257483
# 3        0.664026
# 7        0.745362
# 28       1.000000

# %% [markdown]
# # Memisahkan variabel yang akan digunakan dan di cleansing

# %%
variabel = data[['SiO2', 'Al203', 'Fe203', 'MgO',	'CaO',	'SO3',	'LOI',	'FL',	'Insol', 'Residu', 'Blaine', 28]]

# %%
variabel.describe()
# Out:
#              SiO2       Al203       Fe203         MgO         CaO         SO3  \
# count  454.000000  454.000000  454.000000  454.000000  454.000000  454.000000
# mean    22.813689    6.396348    3.152486    0.898396   56.556198    1.776590
# std      1.923224    0.549765    0.264753    0.161646    2.166048    0.199005
# min     18.344330    5.208660    2.674810    0.063889   51.130000    1.174820
# 25%     21.621445    6.051345    2.976368    0.820043   55.159022    1.619307
# 50%     22.338120    6.300000    3.084610    0.909100   56.272620    1.755815
# 75%     23.738588    6.619592    3.249015    0.999938   57.880803    1.929865
# max     28.810000    8.300000    4.000000    1.342920   67.870000    2.378100
#
#               LOI          FL       Insol      Residu      Blaine          28
# count  454.000000  454.000000  454.000000  454.000000  454.000000  454.000000
# mean     7.490328    1.228766   11.286748    6.091765  427.302024  339.227259
# std      2.215252    0.404701    2.556303    1.600729   35.841258   36.626450
# min      2.227327    0.086400    0.729416    2.570000  313.610756  242.099900
# 25%      5.759662    0.949807    9.839869    4.860000  403.497792  314.475028
# 50%      8.255964    1.197600   11.052998    6.086870  429.189992  335.372072
# 75%      9.241082    1.485988   12.760351    7.007500  452.523248  359.327220
# max     11.487026    3.302970   19.195540   11.884550  515.831366  462.283388

# %%
variabel.corr()
# Out:
#             SiO2     Al203     Fe203       MgO       CaO       SO3       LOI  \
# SiO2    1.000000  0.795315  0.481150  0.010572 -0.499528 -0.276211 -0.671216
# Al203   0.795315  1.000000  0.771145 -0.280394 -0.202102 -0.379667 -0.705463
# Fe203   0.481150  0.771145  1.000000 -0.383638  0.309436 -0.333917 -0.695731
# MgO     0.010572 -0.280394 -0.383638  1.000000 -0.199105  0.368975  0.204581
# CaO    -0.499528 -0.202102  0.309436 -0.199105  1.000000 -0.073582 -0.046354
# SO3    -0.276211 -0.379667 -0.333917  0.368975 -0.073582  1.000000  0.278713
# LOI    -0.671216 -0.705463 -0.695731  0.204581 -0.046354  0.278713  1.000000
# FL      0.109577  0.092827  0.080327 -0.008881  0.118906 -0.174392 -0.168810
# Insol   0.768277  0.624725  0.268719 -0.021146 -0.675303 -0.185363 -0.177542
# Residu  0.279779  0.408551  0.541901 -0.138527  0.242246 -0.171579 -0.434997
# Blaine -0.456225 -0.420438 -0.506753  0.133003 -0.173512  0.147191  0.795279
# 28      0.077115  0.310446  0.407714 -0.237557  0.348994 -0.143131 -0.522115
#
#               FL     Insol    Residu    Blaine        28
# SiO2    0.109577  0.768277  0.279779 -0.456225  0.077115
# Al203   0.092827  0.624725  0.408551 -0.420438  0.310446
# Fe203   0.080327  0.268719  0.541901 -0.506753  0.407714
# MgO    -0.008881 -0.021146 -0.138527  0.133003 -0.237557
# CaO     0.118906 -0.675303  0.242246 -0.173512  0.348994
# SO3    -0.174392 -0.185363 -0.171579  0.147191 -0.143131
# LOI    -0.168810 -0.177542 -0.434997  0.795279 -0.522115
# FL      1.000000 -0.042589  0.164221 -0.216037  0.119818
# Insol  -0.042589  1.000000  0.069155  0.052488 -0.257483
# Residu  0.164221  0.069155  1.000000 -0.477934  0.188905
# Blaine -0.216037  0.052488 -0.477934  1.000000 -0.462006
# 28      0.119818 -0.257483  0.188905 -0.462006  1.000000

# %%
variabel.columns
# Out:
# Index([  'SiO2',  'Al203',  'Fe203',    'MgO',    'CaO',    'SO3',    'LOI',
#            'FL',  'Insol', 'Residu', 'Blaine',       28],
#       dtype='object')

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for col in variabel.columns:
    if plotnumber <= 12:
        ax = plt.subplot(4, 4, plotnumber)
        sns.boxplot(variabel[col])
        plt.xlabel(col, fontsize = 15)

    plotnumber += 1
plt.tight_layout()
plt.show()

# %%
variabel.skew()
# Out:
# SiO2      0.729245
# Al203     1.041739
# Fe203     1.221926
# MgO      -0.606564
# CaO       0.857592
# SO3       0.188181
# LOI      -0.716741
# FL        0.608667
# Insol     0.277911
# Residu    0.548388
# Blaine   -0.174230
# 28        0.640818
# dtype: float64

# %%
plt.figure(figsize=(12, 10))
for i, col in enumerate(variabel.columns):
    plt.subplot(3, 4, i+1)
    sns.histplot(variabel[col], kde=True, color='skyblue')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.title('Distribution of {}'.format(col))

plt.tight_layout()
plt.show()

# %%
mean = variabel[28].mean()
std_dev = variabel[28].std()

# %%
threshold = 2
lower_bound = mean - threshold * std_dev
upper_bound = mean + threshold * std_dev

# %%
variabel = variabel[(variabel[28] >= lower_bound) & (variabel[28] <= upper_bound)]

# %%
variabel.shape
# Out:
# (432, 12)

# %% [markdown]
# # Memisahkan kolom features dan target

# %%
target = variabel[28]

# %%
target = target.reset_index(drop=True)

# %%
target
# Out:
# 0      400.101940
# 1      380.224264
# 2      398.063204
# 3      410.295620
# 4      356.269116
#           ...
# 427    304.791032
# 428    318.042816
# 429    304.791032
# 430    334.352704
# 431    353.211012
# Name: 28, Length: 432, dtype: float64

# %%
features = variabel[['MgO', 'CaO', 'SO3', 'LOI',	'FL',	'Insol']]
features
# Out:
#          MgO       CaO      SO3       LOI        FL      Insol
# 6    0.89000  64.37000  1.86000  2.419758  1.926309   5.566660
# 7    1.03000  56.84000  1.64000  2.636572  1.553845  13.177365
# 8    0.91000  60.02000  1.70000  2.376198  1.555399   8.851149
# 11   0.93000  58.50000  1.35000  2.507743  1.406000  12.592371
# 12   0.94000  56.83000  1.60000  2.782765  1.782038  14.014394
# ..       ...       ...      ...       ...       ...        ...
# 724  1.13000  58.46000  1.76000  9.498707  0.396000   9.618623
# 726  1.07676  59.08322  1.67198  8.328732  0.086400   8.699534
# 727  1.11006  59.09016  1.78500  8.357934  0.100800   8.702595
# 728  1.09012  58.63324  1.81234  8.712950  0.194400   9.593691
# 729  1.21449  59.37500  1.96669  2.984496  0.381600   7.442369
#
# [432 rows x 6 columns]

# %% [markdown]
# # Normalisasi

# %% [markdown]
# ## Outlier dan Skew

# %% [markdown]
# Bisa dilihat dari boxplot bahwa variabel yang memiliki permasalahan outlier di beberapa kolom. Dan sudah dilakukan beberapa normalisasi scaling seperti minmaxscaler, robustscaler dan StandardScaler. namun tidak membuat perubahan.
#
# jika kita melihat dari skew yang terjadi pada data tidak seragam dengan rentang data yang menjadi pencilan sangat beragam dan tidak sedikit. sehingga saya hanya akan menghapus data dengan melihat distribusi variabel target nya saja dimana angka ekstrem yang menjadi pencilan dan kemungkinan akan terjadi di real time sangat kecil.

# %%
# for column in features.columns:
#     if column not in ['MgO', 'LOI']:
#         features[column] += 1
#         features[column] = np.log(features[column])

# %% [markdown]
# ### Melihat kembali skew dan outlier

# %%
features.skew()
# Out:
# MgO     -0.655537
# CaO      0.800604
# SO3      0.160332
# LOI     -0.774361
# FL       0.647945
# Insol    0.462370
# dtype: float64

# %%
target.skew()
# Out:
# 0.2871758698397834

# %%
plt.figure(figsize=(12, 10))
for i, col in enumerate(features.columns):
    plt.subplot(3, 4, i+1)
    sns.histplot(features[col], kde=True, color='skyblue')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.title('Distribution of {}'.format(col))

plt.tight_layout()
plt.show()

# %%
features = features.reset_index(drop=True)

# %%
features
# Out:
#          MgO       CaO      SO3       LOI        FL      Insol
# 0    0.89000  64.37000  1.86000  2.419758  1.926309   5.566660
# 1    1.03000  56.84000  1.64000  2.636572  1.553845  13.177365
# 2    0.91000  60.02000  1.70000  2.376198  1.555399   8.851149
# 3    0.93000  58.50000  1.35000  2.507743  1.406000  12.592371
# 4    0.94000  56.83000  1.60000  2.782765  1.782038  14.014394
# ..       ...       ...      ...       ...       ...        ...
# 427  1.13000  58.46000  1.76000  9.498707  0.396000   9.618623
# 428  1.07676  59.08322  1.67198  8.328732  0.086400   8.699534
# 429  1.11006  59.09016  1.78500  8.357934  0.100800   8.702595
# 430  1.09012  58.63324  1.81234  8.712950  0.194400   9.593691
# 431  1.21449  59.37500  1.96669  2.984496  0.381600   7.442369
#
# [432 rows x 6 columns]

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for col in features.columns:
    if plotnumber <= 12:
        ax = plt.subplot(4, 4, plotnumber)
        sns.boxplot(features[col])
        plt.xlabel(col, fontsize = 15)

    plotnumber += 1
plt.tight_layout()
plt.show()

# %% [markdown]
# # split data

# %%
test_size = 0.4
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=test_size, random_state=42)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Model

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# neural network

# %%
import tensorflow as tf

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(6,)),  # Input layer dengan 6 fitur
    tf.keras.layers.Dense(64, activation='relu'),  # Lapisan tersembunyi dengan 64 neuron dan fungsi aktivasi ReLU
    tf.keras.layers.Dense(1)  # Lapisan output dengan 1 neuron
])

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 9/9 [==============================] - 1s 4ms/step - loss: 113298.7109
# Epoch 2/10
# 9/9 [==============================] - 0s 4ms/step - loss: 113159.7500
# Epoch 3/10
# 9/9 [==============================] - 0s 4ms/step - loss: 113024.5312
# Epoch 4/10
# 9/9 [==============================] - 0s 4ms/step - loss: 112890.3750
# Epoch 5/10
# 9/9 [==============================] - 0s 4ms/step - loss: 112750.9375
# Epoch 6/10
# 9/9 [==============================] - 0s 3ms/step - loss: 112613.3906
# Epoch 7/10
# 9/9 [==============================] - 0s 3ms/step - loss: 112471.9062
# Epoch 8/10
# 9/9 [==============================] - 0s 3ms/step - loss: 112324.8438
# Epoch 9/10
# 9/9 [==============================] - 0s 4ms/step - loss: 112179.5547
# Epoch 10/10
# 9/9 [==============================] - 0s 3ms/step - loss: 112025.3750

# %%
y_test_pred = model.predict(X_test)
# Out:
# 6/6 [==============================] - 0s 2ms/step

# %%
mse = mean_squared_error(y_test, y_test_pred)
r2 = r2_score(y_test, y_test_pred)
print(f'Mean Squared Error: {mse:.4f}')
print(f'R-squared: {r2:.4f}')
# Out:
# Mean Squared Error: 112739.2260
# R-squared: -119.9519

# %% [markdown]
# mlp

# %%
from sklearn.neural_network import MLPRegressor
regr = MLPRegressor(random_state=1, max_iter=3000,hidden_layer_sizes=(5,3)).fit(X_train, y_train)
print('The R2 score of our prediction is %.4f' %(regr.score(X_test, y_test)))
# Out:
# The R2 score of our prediction is -0.4762
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
param_grid = {
    'hidden_layer_sizes': [(5, 3), (10, 5), (20, 10)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'max_iter': [1000, 2000, 3000]
}

# %%
tun = MLPRegressor(random_state=1)

# %%
grid_search = GridSearchCV(regr, param_grid, cv=5, scoring='neg_mean_squared_error')

# %%
grid_search.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (3000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=MLPRegressor(hidden_layer_sizes=(5, 3), max_iter=3000,
#                                     random_state=1),
#              param_grid={'activation': ['relu', 'tanh'],
#                          'hidden_layer_sizes': [(5, 3), (10, 5), (20, 10)],
#                          'max_iter': [1000, 2000, 3000],
#                          'solver': ['adam', 'sgd']},
#              scoring='neg_mean_squared_error')

# %%
best = grid_search.best_estimator_

# %%
best.fit(X_train, y_train)
# Out:
# MLPRegressor(activation='tanh', hidden_layer_sizes=(5, 3), max_iter=1000,
#              random_state=1, solver='sgd')

# %%
y_pred = best.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 933.5482598095565

# %%
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# -0.0015544886609513142

# %% [markdown]
# deep mlp

# %%
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import plot_model

# %%
model = Sequential()
model.add(Dense(128, input_dim=6, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics='mae')

# %%
plot_model(model, to_file='model.png', show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 128)               896
#
#  dense_21 (Dense)            (None, 64)                8256
#
#  dense_22 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 9217 (36.00 KB)
# Trainable params: 9217 (36.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s
# Epoch 23/100
# 9/9 [==============================] - 0s 6ms/step - loss: 40854.8203 - mae: 196.1318 - val_loss: 36533.8789 - val_mae: 185.1708
# Epoch 24/100
# 9/9 [==============================] - 0s 7ms/step - loss: 36254.1211 - mae: 183.4768 - val_loss: 32212.3828 - val_mae: 172.2756
# Epoch 25/100
# 9/9 [==============================] - 0s 8ms/step - loss: 31874.0391 - mae: 170.3816 - val_loss: 28081.3340 - val_mae: 158.7755
# Epoch 26/100
# 9/9 [==============================] - 0s 9ms/step - loss: 27622.0664 - mae: 156.5700 - val_loss: 24000.6113 - val_mae: 143.8829
# Epoch 27/100
# 9/9 [==============================] - 0s 8ms/step - loss: 23639.5391 - mae: 142.2572 - val_loss: 20932.6797 - val_mae: 131.7690
# Epoch 28/100
# 9/9 [==============================] - 0s 6ms/step - loss: 20447.9785 - mae: 130.2927 - val_loss: 17602.9551 - val_mae: 117.4050
# Epoch 29/100
# 9/9 [==============================] - 0s 8ms/step - loss: 17163.6406 - mae: 116.7524 - val_loss: 14902.8223 - val_mae: 106.5268
# Epoch 30/100
# 9/9 [==============================] - 0s 9ms/step - loss: 14365.8262 - mae: 104.4938 - val_loss: 12402.5303 - val_mae: 97.0218
# Epoch 31/100
# 9/9 [==============================] - 0s 6ms/step - loss: 11836.0059 - mae: 92.8608 - val_loss: 10429.3906 - val_mae: 90.4153
# Epoch 32/100
# 9/9 [==============================] - 0s 8ms/step - loss: 9892.8340 - mae: 82.9422 - val_loss: 9092.3066 - val_mae: 85.5253
# Epoch 33/100
# 9/9 [==============================] - 0s 6ms/step - loss: 8369.2168 - mae: 75.2368 - val_loss: 8080.0176 - val_mae: 81.0331
# Epoch 34/100
# 9/9 [==============================] - 0s 8ms/step - loss: 7327.6929 - mae: 69.2874 - val_loss: 7419.5000 - val_mae: 76.7884
# Epoch 35/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6589.8525 - mae: 65.3190 - val_loss: 7134.8628 - val_mae: 74.1439
# Epoch 36/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6101.0659 - mae: 62.4808 - val_loss: 6861.1919 - val_mae: 71.8131
# Epoch 37/100
# 9/9 [==============================] - 0s 6ms/step - loss: 5725.1016 - mae: 60.6808 - val_loss: 6727.6143 - val_mae: 69.4091
# Epoch 38/100
# 9/9 [==============================] - 0s 7ms/step - loss: 5383.5459 - mae: 58.9944 - val_loss: 6639.6841 - val_mae: 68.7702
# Epoch 39/100
# 9/9 [==============================] - 0s 7ms/step - loss: 5076.6313 - mae: 57.2005 - val_loss: 6301.7378 - val_mae: 67.0911
# Epoch 40/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4854.2095 - mae: 56.0184 - val_loss: 6086.3472 - val_mae: 65.0394
# Epoch 41/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4607.0996 - mae: 54.6921 - val_loss: 5920.0054 - val_mae: 64.3341
# Epoch 42/100
# 9/9 [==============================] - 0s 7ms/step - loss: 4363.4893 - mae: 53.2686 - val_loss: 5777.2012 - val_mae: 62.8054
# Epoch 43/100
# 9/9 [==============================] - 0s 8ms/step - loss: 4154.3154 - mae: 52.1103 - val_loss: 5432.8838 - val_mae: 61.7320
# Epoch 44/100
# 9/9 [==============================] - 0s 7ms/step - loss: 3958.3320 - mae: 50.8295 - val_loss: 5274.0063 - val_mae: 60.0566
# Epoch 45/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3757.1804 - mae: 49.7709 - val_loss: 5136.4653 - val_mae: 58.8979
# Epoch 46/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3576.1592 - mae: 48.5950 - val_loss: 4911.3525 - val_mae: 58.7662
# Epoch 47/100
# 9/9 [==============================] - 0s 7ms/step - loss: 3419.6191 - mae: 47.5930 - val_loss: 4783.3970 - val_mae: 57.7816
# Epoch 48/100
# 9/9 [==============================] - 0s 6ms/step - loss: 3289.6736 - mae: 46.6526 - val_loss: 4653.0381 - val_mae: 56.6087
# Epoch 49/100
# 9/9 [==============================] - 0s 8ms/step - loss: 3180.0107 - mae: 45.8530 - val_loss: 4560.8501 - val_mae: 54.7572
# Epoch 50/100
# 9/9 [==============================] - 0s 6ms/step - loss: 3038.4497 - mae: 44.9452 - val_loss: 4436.1514 - val_mae: 54.5016
# Epoch 51/100
# 9/9 [==============================] - 0s 6ms/step - loss: 2909.1035 - mae: 44.0092 - val_loss: 4326.1255 - val_mae: 52.9911
# Epoch 52/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2770.9294 - mae: 42.9626 - val_loss: 4221.2554 - val_mae: 52.6567
# Epoch 53/100
# 9/9 [==============================] - 0s 10ms/step - loss: 2642.5017 - mae: 42.0050 - val_loss: 4144.7456 - val_mae: 51.7869
# Epoch 54/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2515.1245 - mae: 40.9796 - val_loss: 3888.2605 - val_mae: 50.3689
# Epoch 55/100
# 9/9 [==============================] - 0s 10ms/step - loss: 2399.5527 - mae: 40.1775 - val_loss: 3840.4451 - val_mae: 49.0790
# Epoch 56/100
# 9/9 [==============================] - 0s 8ms/step - loss: 2299.8127 - mae: 39.4195 - val_loss: 3751.8594 - val_mae: 48.2218
# Epoch 57/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2201.2783 - mae: 38.5155 - val_loss: 3662.9419 - val_mae: 47.9105
# Epoch 58/100
# 9/9 [==============================] - 0s 7ms/step - loss: 2100.8347 - mae: 37.8295 - val_loss: 3500.8853 - val_mae: 46.8390
# Epoch 59/100
# 9/9 [==============================] - 0s 9ms/step - loss: 2022.7135 - mae: 36.8858 - val_loss: 3444.5930 - val_mae: 46.4919
# Epoch 60/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1939.7877 - mae: 36.1302 - val_loss: 3394.8142 - val_mae: 44.3396
# Epoch 61/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1874.4666 - mae: 35.4931 - val_loss: 3242.3333 - val_mae: 44.0057
# Epoch 62/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1781.8429 - mae: 34.6102 - val_loss: 3001.5886 - val_mae: 43.6545
# Epoch 63/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1720.7355 - mae: 33.9216 - val_loss: 3014.7375 - val_mae: 41.6453
# Epoch 64/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1658.3237 - mae: 33.3511 - val_loss: 2880.8086 - val_mae: 39.8447
# Epoch 65/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1599.1720 - mae: 32.7238 - val_loss: 2683.9355 - val_mae: 40.2966
# Epoch 66/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1556.7057 - mae: 32.0377 - val_loss: 2681.4827 - val_mae: 38.7153
# Epoch 67/100
# 9/9 [==============================] - 0s 9ms/step - loss: 1501.8567 - mae: 31.6531 - val_loss: 2623.7524 - val_mae: 39.0617
# Epoch 68/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1451.5229 - mae: 31.1336 - val_loss: 2532.7549 - val_mae: 37.9517
# Epoch 69/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1405.0266 - mae: 30.5209 - val_loss: 2443.5200 - val_mae: 37.9261
# Epoch 70/100
# 9/9 [==============================] - 0s 9ms/step - loss: 1377.1287 - mae: 30.1773 - val_loss: 2493.1865 - val_mae: 36.7574
# Epoch 71/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1344.0806 - mae: 29.8625 - val_loss: 2459.6995 - val_mae: 36.4532
# Epoch 72/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1308.4138 - mae: 29.2692 - val_loss: 2382.7759 - val_mae: 36.5936
# Epoch 73/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1278.7339 - mae: 28.9646 - val_loss: 2267.9265 - val_mae: 36.0297
# Epoch 74/100
# 9/9 [==============================] - 0s 8ms/step - loss: 1251.7368 - mae: 28.5040 - val_loss: 2307.6123 - val_mae: 35.4224
# Epoch 75/100
# 9/9 [==============================] - 0s 9ms/step - loss: 1220.6748 - mae: 28.2392 - val_loss: 2215.4741 - val_mae: 35.2021
# Epoch 76/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1191.9335 - mae: 27.8137 - val_loss: 2118.1865 - val_mae: 34.3457
# Epoch 77/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1165.1370 - mae: 27.3393 - val_loss: 2068.0422 - val_mae: 32.4271
# Epoch 78/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1144.3756 - mae: 27.2622 - val_loss: 2045.7496 - val_mae: 32.7403
# Epoch 79/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1125.7784 - mae: 26.9534 - val_loss: 2106.4292 - val_mae: 32.1254
# Epoch 80/100
# 9/9 [==============================] - 0s 7ms/step - loss: 1112.8241 - mae: 26.9149 - val_loss: 2003.1383 - val_mae: 31.6632
# Epoch 81/100
# 9/9 [==============================] - 0s 9ms/step - loss: 1080.9205 - mae: 26.4537 - val_loss: 1964.5398 - val_mae: 32.0230
# Epoch 82/100
# 9/9 [==============================] - 0s 9ms/step - loss: 1058.3995 - mae: 26.0394 - val_loss: 1957.1855 - val_mae: 31.0593
# Epoch 83/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1046.1790 - mae: 25.8352 - val_loss: 1829.3943 - val_mae: 30.6845
# Epoch 84/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1022.7695 - mae: 25.5160 - val_loss: 1796.9064 - val_mae: 31.6666
# Epoch 85/100
# 9/9 [==============================] - 0s 6ms/step - loss: 1015.3818 - mae: 25.3437 - val_loss: 1890.4698 - val_mae: 30.5875
# Epoch 86/100
# 9/9 [==============================] - 0s 6ms/step - loss: 998.3669 - mae: 25.0884 - val_loss: 1895.2169 - val_mae: 30.6138
# Epoch 87/100
# 9/9 [==============================] - 0s 10ms/step - loss: 988.0480 - mae: 24.9703 - val_loss: 1795.6802 - val_mae: 29.9267
# Epoch 88/100
# 9/9 [==============================] - 0s 6ms/step - loss: 963.7919 - mae: 24.6006 - val_loss: 1780.2328 - val_mae: 29.1942
# Epoch 89/100
# 9/9 [==============================] - 0s 9ms/step - loss: 953.3658 - mae: 24.5153 - val_loss: 1739.6001 - val_mae: 29.5146
# Epoch 90/100
# 9/9 [==============================] - 0s 6ms/step - loss: 937.7944 - mae: 24.2342 - val_loss: 1831.1519 - val_mae: 29.6754
# Epoch 91/100
# 9/9 [==============================] - 0s 7ms/step - loss: 924.0960 - mae: 24.2140 - val_loss: 1817.5449 - val_mae: 29.4596
# Epoch 92/100
# 9/9 [==============================] - 0s 6ms/step - loss: 916.5175 - mae: 24.0444 - val_loss: 1609.1625 - val_mae: 29.5263
# Epoch 93/100
# 9/9 [==============================] - 0s 6ms/step - loss: 906.2086 - mae: 23.6957 - val_loss: 1650.3285 - val_mae: 28.7118
# Epoch 94/100
# 9/9 [==============================] - 0s 6ms/step - loss: 892.0883 - mae: 23.6250 - val_loss: 1560.3746 - val_mae: 28.5591
# Epoch 95/100
# 9/9 [==============================] - 0s 6ms/step - loss: 884.8963 - mae: 23.6456 - val_loss: 1506.6694 - val_mae: 27.2799
# Epoch 96/100
# 9/9 [==============================] - 0s 6ms/step - loss: 870.2734 - mae: 23.2431 - val_loss: 1416.2939 - val_mae: 27.1857
# Epoch 97/100
# 9/9 [==============================] - 0s 6ms/step - loss: 856.7663 - mae: 22.9277 - val_loss: 1432.9487 - val_mae: 27.1218
# Epoch 98/100
# 9/9 [==============================] - 0s 9ms/step - loss: 853.4432 - mae: 23.1384 - val_loss: 1455.0961 - val_mae: 26.1663
# Epoch 99/100
# 9/9 [==============================] - 0s 8ms/step - loss: 843.4679 - mae: 22.8981 - val_loss: 1434.8853 - val_mae: 26.5548
# Epoch 100/100
# 9/9 [==============================] - 0s 8ms/step - loss: 834.4675 - mae: 22.7661 - val_loss: 1389.6138 - val_mae: 26.1490

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot loss pada setiap epoch
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
predic = model.predict(X_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step

# %%
y_test.shape
# Out:
# (44,)

# %%
X_test.shape
# Out:
# (44, 6)

# %%
predic.shape
# Out:
# (44, 1)

# %%
cek = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': predic.flatten()})

# %%
cek
# Out:
#         Actual   Predicted
# 0   354.230380  361.216431
# 1   365.443428  321.588593
# 2   385.830788  348.581329
# 3   313.455660  306.179901
# 4   337.410808  335.308563
# 5   310.907240  345.227539
# 6   284.913356  316.959808
# 7   377.166160  337.559845
# 8   351.681960  357.587555
# 9   291.029564  325.446869
# 10  379.204896  356.426086
# 11  358.307852  338.736755
# 12  293.577984  324.485901
# 13  352.191644  368.203827
# 14  330.275232  299.859222
# 15  308.868504  306.456573
# 16  333.333336  318.521637
# 17  282.874620  312.889893
# 18  286.442408  321.390656
# 19  356.269116  309.497314
# 20  299.694192  311.641144
# 21  334.862388  318.988403
# 22  384.301736  329.764740
# 23  331.804284  329.187225
# 24  410.295620  392.129333
# 25  306.829768  302.701202
# 26  379.714580  356.920135
# 27  344.036700  332.175446
# 28  352.191644  330.080963
# 29  356.778800  323.447754
# 30  350.662592  314.283661
# 31  336.391440  320.589661
# 32  300.203876  317.863098
# 33  345.565752  334.645691
# 34  363.914376  363.576294
# 35  397.553520  401.708221
# 36  318.552500  472.942413
# 37  381.243632  350.020508
# 38  357.798168  344.328857
# 39  401.121308  398.207153
# 40  352.701328  357.695099
# 41  410.805304  409.524536
# 42  348.623856  331.562775
# 43  318.552500  317.568878

# %%
cek.plot.scatter(x='Actual', y='Predicted', color='blue', marker='o', label='Data Points')

# Menambahkan garis diagonal identitas (x=y)
plt.plot([cek['Actual'].min(), cek['Actual'].max()], [cek['Actual'].min(), cek['Actual'].max()], linestyle='--', color='red', label='Identity Line')

plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Scatter Plot with Identity Line')
plt.legend()
plt.show()

# %%
eval = mean_squared_error(y_test, predic)

# %%
eval
# Out:
# 1120.6360853557899

# %% [markdown]
# # DEPLOY

# %%
model.save("kel10", save_format="tf")

# %%
import shutil
shutil.make_archive("/content/kel10", 'zip', "/content/kel10")
# Out:
# '/content/kel10.zip'
